# %%
import spotipy
import spotipy.util as util
import types
# import constants

# %%
def current_user_recently_played(self, limit=50):
    return self._get("me/player/recently-played", limit=limit)


token = util.prompt_for_user_token(
    scope="user-read-recently-played user-read-private user-top-read user-read-currently-playing",
    client_id='4c194a54913b473bb83708683dff2b7e',
    client_secret='08774da49c5a430a9630bb51146fb4e7',
    redirect_uri="http://localhost:7777/callback",
)

spotify = spotipy.Spotify(auth=token)
spotify.current_user_recently_played = types.MethodType(
    current_user_recently_played, spotify
)

history = spotify.current_user_recently_played(limit=50)
# print(history)

# %%
import pandas as pd

# %%
df = pd.DataFrame()
dfdict = {}

for i in range(len(history['items'])):
	feature = spotify.audio_features(history['items'][i]['track']['id'])
	featureList = list(feature[0].values())
	featureList = featureList[:11]
	dfdict[i] = [
		history['items'][i]['track']['id'],
		history['items'][i]['track']['name'],
		history['items'][i]['track']['artists'][0]['name'],
		history['items'][i]['track']['album']['album_type'],
		history['items'][i]['track']['album']['name'],
		history['items'][i]['played_at']
	]
	dfdict[i].extend(featureList)

df = pd.DataFrame.from_dict(dfdict, orient='index', columns=['Song ID','Name', 'Artist', 'Album Type', 'Album Name', 'Played At', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness', 'Acoustics', 'Instrumentalness', 'Liveliness', 'Valance', 'Tempo'])

# %%
df = df.drop(['Mode'], axis=1)
print(df.shape)
df
# Out:
# (50, 16)
#                    Song ID                                           Name  \
# 0   3PPD1wg591kQnsws16mlkS                                        chances
# 1   1FUQZYqWRVL8eaQd7uENlz                                      Serotonin
# 2   7es56D0QedGMsK39wl2yFX                              Happier Than Ever
# 3   0QzuaeCEEOV40Pn7IvKEny                                    double take
# 4   1YlulsUKDduOmC7WxvXYPW                                     Painkiller
# 5   5gsJUCSx0w2fO95Ou78Zpu                                          daisy
# 6   56AXSWLp4R6gBqvkaWTuRj                                 what lovers do
# 7   4UG2Fm0E98LhE2dlNxiAXx        this is what falling in love feels like
# 8   663vZfMh88Uo2bfTx6wiE4                                       Pelikula
# 9   68HocO7fx9z0MgDU0ZPHro                               Every Summertime
# 10  08MFgEQeVLF37EyZ7jcwLc                                           Pano
# 11  6qBFSepqLCuh5tehehc1bd                                Like I Want You
# 12  769Ld8demNhMgVLAQcjTDn                                   sun and moon
# 13  37c5GgK7f8QXCwOayKl2Da                                    Doo Doo Doo
# 14  3lUQpvfWFcxZC3RYAVGE7F                                    I Feel Good
# 15  61Emqg95O9zo1GNOcyxq4Y                                    For Tonight
# 16  63bmIgH9sS6sX5Sc7MetGq                                   Habang Buhay
# 17  458EaCXcB9TRBoJEDVcdcr                               Strawberry Skies
# 18  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 19  769Ld8demNhMgVLAQcjTDn                                   sun and moon
# 20  1GaMFbWeBZeSwgyAEr1s4m                                          altar
# 21  20jLHaXVhMFjwHs1JPjL4S        more than i should (feat. jessie reyez)
# 22  3WnGLAKOeutk6CPmWQ0G2i                           everything interlude
# 23  0jeCoIGrGhw8lnkd5YF0qB                     get me started (feat. syd)
# 24  0B3hRuQLvogv6InPAtI31H              up at night (feat. justin bieber)
# 25  5v8oHydXFHM1je05EFyIdw                                   wish i never
# 26  5NZMLV6AWI3O32RMu4dUg7                              shooter interlude
# 27  2OqS1qDeZpXDL7VsTq4Fci                 any given sunday (feat. blxst)
# 28  5tDyUiXPUZDIx8nnZvRTMl                                   little story
# 29  54IbnYEdA3ymfxv07WgN3b                          Your Teeth In My Neck
# 30  5HGU08aDQkOjwogqE3SwhG                   CYANIDE REMIX (feat. Koffee)
# 31  5JycxhApZmzbA4xSwvqh6k                                      All To Me
# 32  3iqlzKw1tLt6tXZyKWV0fZ                                       SOMEBODY
# 33  7Bar1kLTmsRmH6FCKKMEyU                                  Hit Different
# 34  7E01yTzdhlzS4H4rH2k7HH                                          Naked
# 35  6NNvpTzLuBJV7esytJxA4r                                  Subtle Things
# 36  6VFKuuqSbA1GpMEosUgTwQ                                 Nobody But You
# 37  105d0lOPEis24ZdvOllxJp                      Right Track (feat. Smino)
# 38  3uouaAVXpQR3X8RYkJyitQ                                        CYANIDE
# 39  5fQBa4wkmq28xpSLOQ202K                                    Normal Girl
# 40  5lAnYvAIkSDNXqfo7DyFUm                                     Ain't Shit
# 41  7kPpXYcBqOwUAoRCDoIHm1                                  Put On Repeat
# 42  1DOgkaR5Gqa8JtPEIbQORC                                           Over
# 43  5uXO1sjZ7VbNKexKaFRna3       Please Do Not Lean (feat. BADBADNOTGOOD)
# 44  4C79MQWKw9ov99q8AXXBpe                                            Web
# 45  6zIen2DYr2t19vbwqgORY2        Scenic Drive (feat. Ari Lennox & Smino)
# 46  68HocO7fx9z0MgDU0ZPHro                               Every Summertime
# 47  3DarAbFujv6eYNliUTyqtz                       Kiss Me More (feat. SZA)
# 48  2shEeQzAAL3nnOXfB5pJXx                          IMPORTED (with 6LACK)
# 49  3cQmqM0awej9iAESjhKrI9                               Confidently Lost
#
#              Artist   Album Type  \
# 0              thuy        album
# 1             Nic D       single
# 2              ASTN       single
# 3             dhruv        album
# 4              Ruel        album
# 5       Arden Jones       single
# 6             anees       single
# 7              JVKE       single
# 8     Janine Teñoso       single
# 9              NIKI       single
# 10     Zack Tabudlo       single
# 11           Giveon        album
# 12            anees       single
# 13            Llunr       single
# 14      Pink Sweat$       single
# 15           Giveon       single
# 16     Zack Tabudlo        album
# 17       Kid Travis        album
# 18      Post Malone  compilation
# 19            anees       single
# 20          Kehlani        album
# 21          Kehlani        album
# 22          Kehlani        album
# 23          Kehlani        album
# 24          Kehlani        album
# 25          Kehlani        album
# 26          Kehlani        album
# 27          Kehlani        album
# 28          Kehlani        album
# 29       Kali Uchis        album
# 30    Daniel Caesar       single
# 31           Giveon        album
# 32            keshi        album
# 33              SZA       single
# 34         Doja Cat        album
# 35  Sabrina Claudio        album
# 36           Sonder       single
# 37              Syd        album
# 38    Daniel Caesar        album
# 39              SZA        album
# 40         Doja Cat        album
# 41  Sabrina Claudio        album
# 42       Lucky Daye       single
# 43    Daniel Caesar       single
# 44        070 Shake       single
# 45           Khalid        album
# 46             NIKI       single
# 47         Doja Cat        album
# 48     Jessie Reyez        album
# 49  Sabrina Claudio        album
#
#                                            Album Name  \
# 0                                   i hope u see this
# 1                                           Serotonin
# 2                                   Happier Than Ever
# 3                                            rapunzel
# 4                                           Free Time
# 5                                          age tape 1
# 6                                      what lovers do
# 7             this is what falling in love feels like
# 8                                            Pelikula
# 9                                    Every Summertime
# 10                                               Pano
# 11                                          TAKE TIME
# 12                                       sun and moon
# 13                                        Doo Doo Doo
# 14                                        I Feel Good
# 15                                        For Tonight
# 16                                            Episode
# 17                                   Strawberry Skies
# 18  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 19                                       sun and moon
# 20                                    blue water road
# 21                                    blue water road
# 22                                    blue water road
# 23                                    blue water road
# 24                                    blue water road
# 25                                    blue water road
# 26                                    blue water road
# 27                                    blue water road
# 28                                    blue water road
# 29                                          Isolation
# 30                       CYANIDE REMIX (feat. Koffee)
# 31           When It's All Said And Done... Take Time
# 32                                            GABRIEL
# 33                                      Hit Different
# 34                                Planet Her (Deluxe)
# 35                                 Based On A Feeling
# 36                                     Nobody But You
# 37                                 Broken Hearts Club
# 38                                      CASE STUDY 01
# 39                                               Ctrl
# 40                                         Planet Her
# 41                                 Based On A Feeling
# 42                                               Over
# 43                                 Please Do Not Lean
# 44                                                Web
# 45                            Scenic Drive (The Tape)
# 46                                   Every Summertime
# 47                                         Planet Her
# 48                        BEFORE LOVE CAME TO KILL US
# 49                                   Confidently Lost
#
#                    Played At  Danceability  Energy  Key  Loudness  \
# 0   2022-05-19T18:30:00.676Z         0.748   0.472    3    -9.150
# 1   2022-05-19T18:27:12.461Z         0.810   0.497    1    -7.755
# 2   2022-05-19T18:24:41.380Z         0.667   0.457    6    -6.885
# 3   2022-05-19T18:22:51.615Z         0.656   0.436    8   -11.141
# 4   2022-05-19T18:06:22.700Z         0.683   0.420    5    -6.510
# 5   2022-05-19T18:02:48.303Z         0.841   0.441    0    -6.416
# 6   2022-05-19T18:01:25.262Z         0.931   0.474   10   -10.170
# 7   2022-05-19T17:58:49.605Z         0.424   0.438   11    -5.530
# 8   2022-05-19T17:56:48.933Z         0.676   0.259    6   -12.127
# 9   2022-05-19T17:53:23.838Z         0.628   0.676    6    -4.227
# 10  2022-05-19T17:49:47.688Z         0.375   0.457    3    -7.018
# 11  2022-05-19T17:45:32.820Z         0.678   0.355   10    -7.757
# 12  2022-05-19T17:41:11.741Z         0.815   0.442    6    -7.462
# 13  2022-05-19T17:38:38.929Z         0.751   0.382    9    -9.097
# 14  2022-05-19T17:35:52.160Z         0.803   0.750   11    -4.670
